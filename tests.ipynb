# %%
from tests import *

# %%
if __name__ == '__main__':

    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# суммарное расстояние = 16.0 индекс центрального региона = 290
# ..........
# Все точки используются в триангуляции.
# Выпуклость триангуляции сохранена: True
# dist_test False -1.0
#
# [Polyhedra] Построение диаграммы Вороного для тестов...
# суммарное расстояние = 16.0 индекс центрального региона = 290
# ......
# ----------------------------------------------------------------------
# Ran 16 tests in 1.176s
#
# OK
# Все точки используются в триангуляции.
# Выпуклость триангуляции сохранена: True
